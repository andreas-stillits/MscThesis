# %%
import numpy as np
import open3d as o3d
from skimage import measure

# --- Load & (optional) quick clean of the source mesh ---
voxels = np.load("data/sphere.npy")
verts, faces, normals, values = measure.marching_cubes(voxels, spacing=(1.0,1.0,1.0), level=0.5)
src = o3d.geometry.TriangleMesh()
src.vertices = o3d.utility.Vector3dVector(verts)
src.triangles = o3d.utility.Vector3iVector(faces)
src.remove_duplicated_vertices(); src.remove_degenerate_triangles()
src.remove_duplicated_triangles(); src.remove_unreferenced_vertices()
src.remove_non_manifold_edges()  # doesn't guarantee repair, but helps
src.compute_vertex_normals()

print("loaded and cleaned...")


# --- 1) Near-uniform resampling on the surface ---
# Choose a target edge length h (units = your model units)
h = 2  # example; tune
surf_area = src.get_surface_area()
n_pts = int(2 * surf_area / (np.sqrt(3)/4 * h*h))
pcd = src.sample_points_poisson_disk(n_pts, init_factor=5, pcl=None)

# --- 2) Normals: robust estimation + consistent orientation ---
pcd.estimate_normals(
    search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=2.5*h, max_nn=60)
)
# Make normals globally consistent so Ball Pivoting has a single "inside"
pcd.orient_normals_consistent_tangent_plane(k=50)

# --- 3) Ball Pivoting reconstruction (watertight if input is good) ---
radii = [h, h*1.5, h*2.0]  # Try a few radii for robustness
mesh_raw = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
    pcd, o3d.utility.DoubleVector(radii)
 )

print("reconstructed...")

# --- 4) Clean, smooth (non-shrinking), orient, verify ---
mesh_raw.remove_duplicated_vertices(); mesh_raw.remove_degenerate_triangles()
mesh_raw.remove_duplicated_triangles(); mesh_raw.remove_unreferenced_vertices()
mesh_raw.remove_non_manifold_edges()
mesh_raw = mesh_raw.filter_smooth_taubin(number_of_iterations=30)  # mild, non-shrinking
mesh_raw.orient_triangles()  # consistent winding
mesh_raw.compute_vertex_normals()

print("Watertight:", mesh_raw.is_watertight())
print("Edge-manifold (no boundary):", mesh_raw.is_edge_manifold())
print("Vertex-manifold:", mesh_raw.is_vertex_manifold())

o3d.visualization.draw_geometries([mesh_raw])
# Out:
# loaded and cleaned...
# reconstructed...
# Watertight: False
# Edge-manifold (no boundary): True
# Vertex-manifold: True
